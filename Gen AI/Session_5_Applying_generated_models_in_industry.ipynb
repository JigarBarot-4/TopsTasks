# %% [markdown]
# 1.
# Use ChatGPT to summarize a 3-paragraph news article about IPL cricket into a single short paragraph, then copy both the original and summary into a file called ipl_summary.txt.

# %% [markdown]
# ORIGINAL ARTICLE
#
# Royal Challengers Bengaluru (RCB) ended their long wait for an Indian Premier League title by defeating Punjab Kings by six runs in the IPL 2025 final at the Narendra Modi Stadium in Ahmedabad. After years of near misses and three previous final defeats, RCB finally lifted their maiden IPL trophy. Virat Kohli contributed 43 runs and played a key role in helping the team post a competitive total.
#
# Batting first, RCB scored 190/9 in their 20 overs. Punjab Kings began the chase confidently but struggled to maintain momentum against disciplined bowling from RCB. Krunal Pandya delivered a match-winning spell, taking crucial wickets and restricting the scoring rate during the middle overs.
#
# When Punjab Kings finished on 184/7, RCB secured a historic six-run victory. The win sparked emotional celebrations, especially for Virat Kohli, who had spent his entire IPL career with the franchise. The triumph ended an 18-year wait for the title and became one of the most memorable moments in IPL history.
#
# SUMMARY
#
# Royal Challengers Bengaluru won their first-ever IPL title in 2025 by defeating Punjab Kings by six runs in the final at Ahmedabad. Led by important contributions from Virat Kohli and a match-winning bowling performance from Krunal Pandya, RCB ended an 18-year wait for the championship and celebrated a historic victory.

# %% [markdown]
# 2.
# Create a simple Q&A chatbot for Zomato-style restaurant info using any language or platform you know (Python, JavaScript, etc.): given a restaurant name and cuisine, return a canned response like 'Yes, Pizza Palace serves Italian cuisine.'

# %%
# Restaurant database
restaurants = {
    "Pizza Palace": "Italian",
    "Spice Garden": "Indian",
    "Dragon Wok": "Chinese",
    "Burger Hub": "American"
}

# Chatbot function
def restaurant_chatbot(restaurant_name, cuisine):
    if restaurant_name in restaurants:
        if restaurants[restaurant_name].lower() == cuisine.lower():
            return f"Yes, {restaurant_name} serves {cuisine} cuisine."
        else:
            return f"No, {restaurant_name} serves {restaurants[restaurant_name]} cuisine, not {cuisine}."
    else:
        return f"Sorry, information for {restaurant_name} is not available."

# Example usage
restaurant = input("Enter restaurant name: ")
cuisine = input("Enter cuisine: ")

response = restaurant_chatbot(restaurant, cuisine)
print(response)
# Out:
# No, Pizza Palace serves Italian cuisine, not indian.

# %% [markdown]
# 3.
# Generate an original food dish image using DALL·E (or Bing Image Creator) with a prompt like 'A futuristic Gujarati thali with neon colors', then save and submit the image file.<br><br><em><strong>Hint:</strong> Try different prompt variations to get a more creative result.</em>

# %% [markdown]
# ![ChatGPT Image Jun 12, 2026, 10_03_47 AM.png](<attachment:ChatGPT Image Jun 12, 2026, 10_03_47 AM.png>)

# %% [markdown]
# 4.
# Use GitHub Copilot or ChatGPT to help you write a function that takes a list of song names and returns only those that start with the letter 'S', like a Spotify playlist filter.<br><br><em><strong>Constraint:</strong> You must show the prompt you used and the code Copilot or ChatGPT generated.</em>

# %% [markdown]
# ## prompt
#
# Give me a python function which returns songs which start with s

# %%
def filter_songs_starting_with_s(song_list):
    return [song for song in song_list if song.startswith('S')]

# Example playlist
playlist = [
    "Shape of You",
    "Believer",
    "Senorita",
    "Sunflower",
    "Perfect",
    "Stay"
]

# Filter songs
filtered_playlist = filter_songs_starting_with_s(playlist)

print("Songs starting with 'S':")
print(filtered_playlist)
# Out:
# Songs starting with 'S':
# ['Shape of You', 'Senorita', 'Sunflower', 'Stay']

# %% [markdown]
# 5.
# List two production challenges companies face when using generative AI models for chatbots in apps like BookMyShow or Myntra, and suggest one solution for each challenge.

# %% [markdown]
# # Production Challenges of Generative AI Chatbots
#
# | Challenge | Description | Possible Solution |
# |------------|-------------|------------------|
# | **Hallucinations (Incorrect Information)** | The chatbot may generate inaccurate or misleading responses, such as giving wrong movie timings on BookMyShow or incorrect product details on Myntra. | Use **Retrieval-Augmented Generation (RAG)** to fetch information from verified databases and APIs before generating a response. |
# | **High Latency and Cost** | Large AI models require significant computing resources, leading to slow response times and high operational costs when serving millions of users. | Use **smaller optimized models**, response caching, and model quantization to reduce inference time and infrastructure costs. |
#
# ## Example
#
# - **BookMyShow:** A chatbot might incorrectly state that a movie is available at a theater when it is not. Using real-time theater and ticketing APIs can ensure accurate responses.
#
# - **Myntra:** A chatbot serving millions of customers during a sale may become slow and expensive. Deploying optimized models and caching common queries can improve speed and reduce costs.
#
# ## Summary
#
# 1. **Hallucinations** → Solve with **RAG and verified data sources**.
# 2. **High latency/cost** → Solve with **model optimization, caching, and efficient deployment**.
